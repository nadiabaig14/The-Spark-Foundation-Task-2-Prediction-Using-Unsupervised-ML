# %% [markdown]
# Author Nadia Bibi

# %% [markdown]
# # The Spark Foundation Task **2**

# %% [markdown]
# # Prediction Using Unsupervised Machine Learning,K-Mean Clustering

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import datasets

# Load the iris dataset
iris = datasets.load_iris()
iris_df = pd.DataFrame(iris.data, columns = iris.feature_names)
iris_df.head() # See the first 5 rows
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
import pandas as pd
import numpy as np

iris_df = pd.read_csv('/content/Iris.csv')

# random NumPy array with integers
random_array = np.random.randint(1, 10, size=(150, 2))

# numeric columns for operations
numeric_columns = ['SepalLengthCm', 'SepalWidthCm']

# Perform basic operations on the selected columns
addition_result = iris_df[numeric_columns] + random_array
subtraction_result = iris_df[numeric_columns] - random_array
multiplication_result = iris_df[numeric_columns] * random_array
division_result = iris_df[numeric_columns] / random_array

# Display the results of each operation
print("Addition Result:")
print(addition_result.head())

print(subtraction_result.head())

print(multiplication_result.head())

print(division_result.head())
# Out:
# Addition Result:
#    SepalLengthCm  SepalWidthCm
# 0            9.1           8.5
# 1            8.9           9.0
# 2            5.7           4.2
# 3           12.6           6.1
# 4            8.0           9.6
#    SepalLengthCm  SepalWidthCm
# 0            1.1          -1.5
# 1            0.9          -3.0
# 2            3.7           2.2
# 3           -3.4           0.1
# 4            2.0          -2.4
#    SepalLengthCm  SepalWidthCm
# 0           20.4          17.5
# 1           19.6          18.0
# 2            4.7           3.2
# 3           36.8           9.3
# 4           15.0          21.6
#    SepalLengthCm  SepalWidthCm
# 0       1.275000      0.700000
# 1       1.225000      0.500000
# 2       4.700000      3.200000
# 3       0.575000      1.033333
# 4       1.666667      0.600000

# %%
import pandas as pd

df = pd.read_csv('/content/Iris.csv')

# Data Cleaning
# Remove rows with missing values (NaN) in any column
df.dropna(inplace=True)

# Remove duplicate rows
df.drop_duplicates(inplace=True)

# Data Analysis
# Calculate the mean for a specific column ('column_name')
mean_value = df['PetalLengthCm'].mean()
print(f"Mean for 'column_name': {mean_value}")

# Calculate the median for a specific column ('column_name')
median_value = df['PetalLengthCm'].median()
print(f"Median for 'column_name': {median_value}")

# Calculate the mode for a specific column ('column_name')
mode_value = df['PetalLengthCm'].mode().iloc[0]
print(f"Mode for 'column_name': {mode_value}")
# Out:
# Mean for 'column_name': 3.758666666666666
# Median for 'column_name': 4.35
# Mode for 'column_name': 1.5

# %%
import pandas as pd
import matplotlib.pyplot as plt

iris_df = pd.read_csv('/content/Iris.csv')


plt.figure(figsize=(8, 6))
plt.bar(iris_df['Species'], iris_df['SepalLengthCm'], color='green')
plt.xlabel('Species')
plt.ylabel('Sepal Length (cm)')
plt.title('Sepal Length Distribution by Species')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

plt.figure(figsize=(6, 4))
iris_df['Species'].value_counts().plot(kind='bar', color='pink')
plt.xlabel('Species')
plt.ylabel('Count')
plt.title('Species Distribution')
plt.xticks(rotation=0)
plt.tight_layout()

# Show the histogram
plt.show()

# %%
import pandas as pd

# Define range for filtering
min_sepal_length = 1.5
max_sepal_length = 2.5

# Filter rows within the specified date range
filtered_df = iris_df[(iris_df['PetalLengthCm'] >= min_sepal_length) & (iris_df['PetalLengthCm'] <= max_sepal_length)]

# Display the filtered DataFrame
print("Filtered Data:")
print(filtered_df)
# Out:
# Filtered Data:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# 11  12            4.8           3.4            1.6           0.2  Iris-setosa
# 15  16            5.7           4.4            1.5           0.4  Iris-setosa
# 18  19            5.7           3.8            1.7           0.3  Iris-setosa
# 19  20            5.1           3.8            1.5           0.3  Iris-setosa
# 20  21            5.4           3.4            1.7           0.2  Iris-setosa
# 21  22            5.1           3.7            1.5           0.4  Iris-setosa
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

iris_df = pd.read_csv('/content/Iris.csv')

# data for the scatter plot
x = iris_df['SepalLengthCm']
y = iris_df['SepalWidthCm']
species = iris_df['Species']

# marker styles and line colors for each species
marker_styles = ['o', 's', '^']
line_colors = ['blue', 'green', 'red']
species_names = iris_df['Species'].unique()

# custom markers and colors
plt.figure(figsize=(8, 6))
for i, species_name in enumerate(species_names):
    species_data = iris_df[iris_df['Species'] == species_name]
    plt.scatter(
        species_data['SepalLengthCm'],
        species_data['SepalWidthCm'],
        label=species_name,
        marker=marker_styles[i],
        color=line_colors[i],
    )

plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.title('Sepal Length vs. Sepal Width Scatter Plot')
plt.legend(title='Species', labels=species_names)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a figure with three subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Subplot 1: Scatter plot of Sepal Length vs. Sepal Width
axes[0].scatter(iris_df['SepalLengthCm'], iris_df['SepalWidthCm'], marker='o', color='blue')
axes[0].set_title('Sepal Length vs. Sepal Width')
axes[0].set_xlabel('Sepal Length (cm)')
axes[0].set_ylabel('Sepal Width (cm)')

# Subplot 2: Bar chart for Species vs. Petal Length
species_counts = iris_df['Species'].value_counts()
axes[1].bar(species_counts.index, species_counts.values, color=['blue', 'green', 'red'])
axes[1].set_title('Species Distribution')
axes[1].set_xlabel('Species')
axes[1].set_ylabel('Count')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

iris_df = pd.read_csv('/content/Iris.csv')

# Visualization 1: Bar chart of species count
species_counts = iris_df['Species'].value_counts()
plt.figure(figsize=(8, 4))
species_counts.plot(kind='bar', color='skyblue')
plt.title('Species Count')
plt.xlabel('Species')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# Visualization 2: Pie chart of species distribution
plt.figure(figsize=(6, 6))
plt.pie(species_counts, labels=species_counts.index, autopct='%1.1f%%', colors=['lightcoral', 'lightgreen', 'lightskyblue'])
plt.title('Species Distribution')
plt.show()

# Visualization 3: Scatter plot of Sepal Length vs. Sepal Width
plt.figure(figsize=(8, 6))
plt.scatter(iris_df['SepalLengthCm'], iris_df['SepalWidthCm'], c='purple', marker='o', alpha=0.8)
plt.title('Scatter Plot of Sepal Length vs. Sepal Width')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.show()

# Visualization 4: Scatter plot of Petal Length vs. Petal Width with species coloring
plt.figure(figsize=(8, 6))
colors = {'Iris-setosa': 'red', 'Iris-versicolor': 'green', 'Iris-virginica': 'blue'}
plt.scatter(iris_df['PetalLengthCm'], iris_df['PetalWidthCm'], c=iris_df['Species'].map(colors), marker='o', alpha=0.8)
plt.title('Scatter Plot of Petal Length vs. Petal Width')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')

# Add legend for species
legend_labels = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10, label=label)
                 for label, color in colors.items()]
plt.legend(handles=legend_labels, title='Species', loc='best')
plt.show()

# %%
# Finding the optimum number of clusters for k-means classification

x = iris_df.iloc[:, [0, 1, 2, 3]].values

from sklearn.cluster import KMeans
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++',
                    max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)

# Plotting the results onto a line graph,
# `allowing us to observe 'The elbow'
plt.plot(range(1, 11), wcss)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') # Within cluster sum of squares
plt.show()

# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt


#  number of clusters
num_clusters = 3

# Applying k-means clustering
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
iris_df['cluster'] = kmeans.fit_predict(features)

# Visualize the clusters
plt.scatter(features['sepal length (cm)'], features['sepal width (cm)'], c=iris_df['cluster'], cmap='viridis')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, marker='X', c='red', label='Centroids')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.title('K-Means Clustering of Iris Dataset')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
